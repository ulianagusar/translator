# %%
import re

def clean_and_normalize(text):
    # Видалення непотрібних символів та зайвих пробілів
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text)

    # Переведення тексту до нижнього регістру
    text = text.lower()

    return text

def read_file_to_list(file_path):
    lines = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            lines.append(line.strip())
    return lines

def create_sentence_pairs(file1_path, file2_path):
    file1_lines = read_file_to_list(file1_path)
    file2_lines = read_file_to_list(file2_path)

    # Перевіряємо, чи кількість речень в обох файлах однакова
    assert len(file1_lines) == len(file2_lines), "Кількість речень в файлах не співпадає."

    sentence_pairs = []
    for i in range(len(file1_lines)):
        sentence1 = clean_and_normalize(file1_lines[i])
        sentence2 = clean_and_normalize(file2_lines[i])

        # Перевірка на наявність порожніх рядків
        if sentence1 and sentence2:
            sentence_pairs.append((sentence1, sentence2))

    return sentence_pairs


# Вказуємо шляхи до двох текстових файлів
#file1_path = '/content/output_en.txt'
#file2_path = '/content/output_uk.txt'

file11_path = '/content/english_sentences.txt'
file22_path = '/content/ukrainian_sentences.txt'

#data1 = create_sentence_pairs(file1_path, file2_path)
data2 = create_sentence_pairs(file11_path, file22_path)
#data=data1
data=data2[:80000]
len(data)
# Out:
# 80000

# %%
import random
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import Dataset, DataLoader
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import nltk
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
nltk.download('punkt')



batch_size = 16


train_data, temp_data = train_test_split(data, test_size=0.3, random_state=42)
test_data, val_data = train_test_split(temp_data, test_size=0.5, random_state=42)

def create_vocab_src(data):
    stemmer = PorterStemmer()
    word_list = []
    count=0
    for src_sent, trg_sent in data:
        words = nltk.word_tokenize(src_sent)
        for word in words:
            if stemmer.stem(word) not in word_list:
                count=count+1
                word_list.append(stemmer.stem(word))


    indices = random.sample(range(4, count+4), count)
    word_index = dict(zip(word_list, indices))
    word_index["<pad>"]=0
    word_index["<sos>"]=2
    word_index["<eos>"]=3
    word_index["<OOV>"]=1

    return word_index

def create_vocab_trg(data):
    word_list = []
    count=0
    for src_sent, trg_sent in data:
        for word in trg_sent.split(' '):
            if word not in word_list:
                count=count+1
                word_list.append(word)
    indices = random.sample(range(4, count+4), count)
    word_index = dict(zip(word_list, indices))
    word_index["<pad>"]=0
    word_index["<sos>"]=2
    word_index["<eos>"]=3
    word_index["<OOV>"]=1
    return word_index

# Функція для перетворення тексту у послідовність токенів
def sentence_src_to_tokens(sentence, word_index):
    stemmer = PorterStemmer()
    ans=[]
    words = nltk.word_tokenize(sentence)
    for word in words:
      if word in word_index:
          ans.append(word_index[stemmer.stem(word)])
      else:
          ans.append(word_index["<OOV>"])
    return  ans
def sentence_trg_to_tokens(sentence, word_index):
    ans=[]
    for word in sentence.split():
        if word in word_index:
          ans.append(word_index[word])
        else:
          ans.append(word_index["<OOV>"])
    return  ans


# Функція для паддінгу послідовностей до однакової довжини
def pad_sequences_src(sequences, max_len):
    padded_seqs = []
    for seq in sequences:
        if len(seq) < max_len-1:
            padding_length = max_len - len(seq) - 1
            padded_seqs.append(seq + [3] + [0] * padding_length)
        elif len(seq) == max_len-1:
            padded_seqs.append(seq + [3])
        else:
            truncated_seq = seq[:max_len-1]
            padded_seqs.append(truncated_seq + [3])


    return padded_seqs

def pad_sequences_trg(sequences, max_len):
    trg_input = []
    trg_output = []
    for seq in sequences:
        if len(seq) < max_len-1:
            padding_length = max_len - len(seq) - 1
            trg_input.append([2] + seq + [0] * padding_length)
            trg_output.append(seq + [3] + [0] * padding_length)
        elif len(seq) == max_len-1:
            trg_input.append([2] + seq)
            trg_output.append(seq + [3])
        else:
            truncated_seq = seq[:max_len-1]
            trg_input.append([2] + truncated_seq )
            trg_output.append(truncated_seq + [3])
    return trg_input, trg_output

# Створюємо словники для англійської та української мов
eng_word_index = create_vocab_src(train_data)
ukr_word_index = create_vocab_trg(train_data)

# Підраховуємо розмір словників
eng_vocab_size = len(eng_word_index)
ukr_vocab_size = len(ukr_word_index)



# Перетворюємо речення на послідовності токенів та паддінгуємо їх
train_src = [sentence_src_to_tokens(pair[0], eng_word_index) for pair in train_data]
train_target = [sentence_trg_to_tokens(pair[1], ukr_word_index) for pair in train_data]

val_src = [sentence_src_to_tokens(pair[0], eng_word_index) for pair in val_data]
val_target = [sentence_trg_to_tokens(pair[1], ukr_word_index) for pair in val_data]

max_src_len = 8
max_target_len = 8
train_src_padded = pad_sequences_src(train_src, max_src_len)
train_target_padded_input , train_target_padded_output= pad_sequences_trg(train_target, max_target_len)

val_src_padded = pad_sequences_src(val_src, max_src_len)
val_target_padded_input , val_target_padded_output= pad_sequences_trg(val_target, max_target_len)

class CustomDataset(Dataset):
    def __init__(self, src_list, input_trg_list, output_trg_list):
        super().__init__()
        self.src_data = torch.LongTensor(src_list)
        self.input_trg_data = torch.LongTensor(input_trg_list)
        self.output_trg_data = torch.LongTensor(output_trg_list)


    def make_mask(self):
        e_mask = (self.src_data != pad_id).unsqueeze(1)
        d_mask = (self.input_trg_data != pad_id).unsqueeze(1)

        nopeak_mask = torch.ones([1, seq_len, seq_len], dtype=torch.bool)
        nopeak_mask = torch.tril(nopeak_mask)
        d_mask = d_mask & nopeak_mask

        return e_mask, d_mask

    def __getitem__(self, idx):
        return self.src_data[idx], self.input_trg_data[idx], self.output_trg_data[idx]

    def __len__(self):
        return np.shape(self.src_data)[0]

# Створюємо DataLoader для тренування


train_dataset = CustomDataset(train_src_padded, train_target_padded_input, train_target_padded_output)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = CustomDataset(val_src_padded, val_target_padded_input, val_target_padded_output)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
# Визначаємо модель перекладача
train_dataloader
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip -q glove.6B.zip
# Out:
# --2023-08-05 07:51:46--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2023-08-05 07:51:47--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2023-08-05 07:51:47--  https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  5.36MB/s    in 2m 42s
#
# 2023-08-05 07:54:30 (5.09 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')


import math
learning_rate = 1e-4
batch_size = 16
seq_len = 8
num_heads = 4
num_layers = 3
d_model = 100
d_ff = 1024
d_k = d_model // num_heads
drop_out_rate = 0.3
num_epochs = 5
beam_size = 4
class EncoderLayer(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_norm_1 = LayerNormalization()
        self.multihead_attention = MultiheadAttention()
        self.drop_out_1 = nn.Dropout(drop_out_rate)

        self.layer_norm_2 = LayerNormalization()
        self.feed_forward = FeedFowardLayer()
        self.drop_out_2 = nn.Dropout(drop_out_rate)

    def forward(self, x, e_mask):
        x_1 = self.layer_norm_1(x)
        x = x + self.drop_out_1(
            self.multihead_attention(x_1, x_1, x_1, mask=e_mask)
        )
        x_2 = self.layer_norm_2(x)
        x = x + self.drop_out_2(self.feed_forward(x_2))

        return x


class DecoderLayer(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_norm_1 = LayerNormalization()
        self.masked_multihead_attention = MultiheadAttention()
        self.drop_out_1 = nn.Dropout(drop_out_rate)

        self.layer_norm_2 = LayerNormalization()
        self.multihead_attention = MultiheadAttention()
        self.drop_out_2 = nn.Dropout(drop_out_rate)

        self.layer_norm_3 = LayerNormalization()
        self.feed_forward = FeedFowardLayer()
        self.drop_out_3 = nn.Dropout(drop_out_rate)

    def forward(self, x, e_output, e_mask,  d_mask):
        x_1 = self.layer_norm_1(x)
        x = x + self.drop_out_1(self.masked_multihead_attention(x_1, x_1, x_1, mask=d_mask))
        x_2 = self.layer_norm_2(x)
        x = x + self.drop_out_2(self.multihead_attention(x_2, e_output, e_output, mask=e_mask))
        x_3 = self.layer_norm_3(x)
        x = x + self.drop_out_3(self.feed_forward(x_3))

        return x


class MultiheadAttention(nn.Module):
    def __init__(self):
        super().__init__()
        self.inf = 1e9

        self.w_q = nn.Linear(d_model, d_model)
        self.w_k = nn.Linear(d_model, d_model)
        self.w_v = nn.Linear(d_model, d_model)

        self.dropout = nn.Dropout(drop_out_rate)
        self.attn_softmax = nn.Softmax(dim=-1)

        self.w_0 = nn.Linear(d_model, d_model)

    def forward(self, q, k, v, mask=None):
        input_shape = q.shape

        q = self.w_q(q).view(input_shape[0], -1, num_heads, d_k)
        k = self.w_k(k).view(input_shape[0], -1, num_heads, d_k)
        v = self.w_v(v).view(input_shape[0], -1, num_heads, d_k)

        q = q.transpose(1, 2)
        k = k.transpose(1, 2)
        v = v.transpose(1, 2)

        attn_values = self.self_attention(q, k, v, mask=mask)
        concat_output = attn_values.transpose(1, 2)\
            .contiguous().view(input_shape[0], -1, d_model)

        return self.w_0(concat_output)

    def self_attention(self, q, k, v, mask=None):
        attn_scores = torch.matmul(q, k.transpose(-2, -1))
        attn_scores = attn_scores / math.sqrt(d_k)

        if mask is not None:
            mask = mask.unsqueeze(1)
            attn_scores = attn_scores.masked_fill_(mask == 0, -1 * self.inf)

        attn_distribs = self.attn_softmax(attn_scores)

        attn_distribs = self.dropout(attn_distribs)
        attn_values = torch.matmul(attn_distribs, v)

        return attn_values


class FeedFowardLayer(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_1 = nn.Linear(d_model, d_ff, bias=True)
        self.relu = nn.ReLU()
        self.linear_2 = nn.Linear(d_ff, d_model, bias=True)
        self.dropout = nn.Dropout(drop_out_rate)

    def forward(self, x):
        x = self.relu(self.linear_1(x))
        x = self.dropout(x)
        x = self.linear_2(x)

        return x


class LayerNormalization(nn.Module):
    def __init__(self, eps=1e-6):
        super().__init__()
        self.eps = eps
        self.layer = nn.LayerNorm([d_model], elementwise_affine=True, eps=self.eps)

    def forward(self, x):
        x = self.layer(x)

        return x


class PositionalEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        pe_matrix= torch.zeros(seq_len, d_model)

        for pos in range(seq_len):
            for i in range(d_model):
                if i % 2 == 0:
                    pe_matrix[pos, i] = math.sin(pos / (10000 ** (2 * i / d_model)))
                elif i % 2 == 1:
                    pe_matrix[pos, i] = math.cos(pos / (10000 ** (2 * i / d_model)))

        pe_matrix = pe_matrix.unsqueeze(0)
        self.positional_encoding = pe_matrix.to(device=device).requires_grad_(False)

    def forward(self, x):
        x = x * math.sqrt(d_model)
        x = x + self.positional_encoding

        return x

class Transformer(nn.Module):
    def __init__(self, src_vocab_size, trg_vocab_size,pretrained_embeddings):
        super().__init__()
        self.src_vocab_size = src_vocab_size
        self.trg_vocab_size = trg_vocab_size
        self.src_embedding = nn.Embedding(self.src_vocab_size, d_model)
        self.src_embedding.weight.data.copy_(torch.from_numpy(pretrained_embeddings))
        self.trg_embedding = nn.Embedding(self.trg_vocab_size, d_model)
        self.positional_encoder = PositionalEncoder()
        self.encoder = Encoder()
        self.decoder = Decoder()
        self.output_linear = nn.Linear(d_model, self.trg_vocab_size)
        self.softmax = nn.LogSoftmax(dim=-1)

    def forward(self, src_input, trg_input, e_mask=None, d_mask=None):
        src_input = self.src_embedding(src_input)

        trg_input = self.trg_embedding(trg_input)
        src_input = self.positional_encoder(src_input)
        trg_input = self.positional_encoder(trg_input)

        e_output = self.encoder(src_input, e_mask)
        d_output = self.decoder(trg_input, e_output, e_mask, d_mask)

        output = self.softmax(self.output_linear(d_output))

        return output


class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.ModuleList([EncoderLayer() for i in range(num_layers)])
        self.layer_norm = LayerNormalization()

    def forward(self, x, e_mask):
        for i in range(num_layers):
            x = self.layers[i](x, e_mask)

        return self.layer_norm(x)


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.ModuleList([DecoderLayer() for i in range(num_layers)])
        self.layer_norm = LayerNormalization()

    def forward(self, x, e_output, e_mask, d_mask):
        for i in range(num_layers):
            x = self.layers[i](x, e_output, e_mask, d_mask)

        return self.layer_norm(x)

# %%
import collections
def load_pretrained_embeddings(
    embedding_file,
    word_to_id,
    num_oov_buckets=1,
    case_insensitive_embeddings=True,
):
    vocab_for_pretrain = collections.defaultdict(list)
    for key, value in word_to_id.items():
        vocab_for_pretrain[key].append(value)
    # Fill pretrained embedding matrix.
    with tf.io.gfile.GFile(embedding_file) as embedding:
        pretrained = None

        for line in embedding:
            fields = line.strip().split()
            word = fields[0]

            if pretrained is None:
                pretrained = np.random.normal(
                    size=(len(vocab_for_pretrain) , len(fields) - 1)
                )

            # Lookup word in the vocabulary.
            if word in vocab_for_pretrain:
                ids = vocab_for_pretrain[word]
                for index in ids:
                    pretrained[index] = np.asarray(fields[1:])

    return pretrained

# %%
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import numpy as np
import sys
import datetime
import torch
import torch.nn as nn
from tqdm import tqdm
import tensorflow as tf
import warnings

warnings.filterwarnings("ignore")

sos_id=2
eos_id=3
pad_id=0
def make_mask(src_input, trg_input):
        e_mask = (src_input != pad_id).unsqueeze(1)
        d_mask = (trg_input != pad_id).unsqueeze(1)

        nopeak_mask = torch.ones([1, seq_len, seq_len], dtype=torch.bool)
        nopeak_mask = torch.tril(nopeak_mask).to(device)
        d_mask = d_mask & nopeak_mask

        return e_mask, d_mask
embedding_file = '/content/glove.6B.100d.txt'
pretrained_embeddings = load_pretrained_embeddings(embedding_file, eng_word_index)

model = Transformer(eng_vocab_size, ukr_vocab_size, pretrained_embeddings).to(device)
optim = torch.optim.Adam(model.parameters(), lr=learning_rate)
best_loss = sys.float_info.max

print("Loading loss function...")
criterion = nn.NLLLoss()
train_loader = train_dataloader
val_loader = val_dataloader

for epoch in range(1, num_epochs + 1):
    model.train()

    train_losses = []
    bleu_scores = []
    start_time = datetime.datetime.now()

    for i, batch in tqdm(enumerate(train_loader)):
        src_input, trg_input, trg_output = batch
        src_input, trg_input, trg_output = src_input.to(device), trg_input.to(device), trg_output.to(device)

        e_mask, d_mask = make_mask(src_input, trg_input)
        output = model(src_input, trg_input, e_mask, d_mask)
        optim.zero_grad()

        loss = criterion(output.view(-1, output.size(-1)), trg_output.view(-1))
        loss.backward()
        optim.step()

        train_losses.append(loss.item())

        # Calculate BLEU score
        predicted = torch.argmax(output, dim=-1).cpu().numpy()
        reference = trg_output.cpu().numpy()
        for p, r in zip(predicted, reference):
            bleu_score = sentence_bleu([r.tolist()], p.tolist())
            bleu_scores.append(bleu_score)

        del src_input, trg_input, trg_output, e_mask, d_mask, output
        torch.cuda.empty_cache()

    # Валідаційна частина
    model.eval()
    val_losses = []
    val_bleu_scores = []

    with torch.no_grad():
        for i, batch in tqdm(enumerate(val_loader)):
            src_input, trg_input, trg_output = batch
            src_input, trg_input, trg_output = src_input.to(device), trg_input.to(device), trg_output.to(device)

            e_mask, d_mask = make_mask(src_input, trg_input)
            output = model(src_input, trg_input, e_mask, d_mask)

            loss = criterion(output.view(-1, output.size(-1)), trg_output.view(-1))
            val_losses.append(loss.item())

            predicted = torch.argmax(output, dim=-1).cpu().numpy()
            reference = trg_output.cpu().numpy()
            for p, r in zip(predicted, reference):
                bleu_score = sentence_bleu([r.tolist()], p.tolist())
                val_bleu_scores.append(bleu_score)

    end_time = datetime.datetime.now()
    training_time = end_time - start_time
    seconds = training_time.seconds
    hours = seconds // 3600
    minutes = (seconds % 3600) // 60
    seconds = seconds % 60

    mean_train_loss = np.mean(train_losses)
    mean_bleu_score = np.mean(bleu_scores)
    mean_val_loss = np.mean(val_losses)
    mean_val_bleu_score = np.mean(val_bleu_scores)
    print(f"#################### Epoch: {epoch} ####################")
    print(f"Train loss: {mean_train_loss} || Mean BLEU score: {mean_bleu_score} || One epoch training time: {hours}hrs {minutes}mins {seconds}secs")
    print(f"Validation loss: {mean_val_loss} || Mean Validation BLEU score: {mean_val_bleu_score}")

    if mean_val_loss < best_loss:
        best_loss = mean_val_loss
        torch.save(model.state_dict(), 'best_model.pth')
# Out:
# Loading loss function...
# 24it [00:04,  6.25it/s]/usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 3500it [10:15,  5.69it/s]
# 750it [00:35, 21.30it/s]
# #################### Epoch: 1 ####################
# Train loss: 3.4842790113857816 || Mean BLEU score: 0.37630488418809716 || One epoch training time: 0hrs 10mins 50secs
# Validation loss: 2.9148073374430337 || Mean Validation BLEU score: 0.39404411675366674
# 3500it [10:34,  5.52it/s]
# 750it [00:33, 22.08it/s]
# #################### Epoch: 2 ####################
# Train loss: 2.745517986706325 || Mean BLEU score: 0.39463161382612316 || One epoch training time: 0hrs 11mins 8secs
# Validation loss: 2.674203867594401 || Mean Validation BLEU score: 0.404041627705153
# 3500it [10:29,  5.56it/s]
# 750it [00:34, 21.92it/s]
# #################### Epoch: 3 ####################
# Train loss: 2.499940338747842 || Mean BLEU score: 0.40102193568698696 || One epoch training time: 0hrs 11mins 3secs
# Validation loss: 2.5248763915697734 || Mean Validation BLEU score: 0.41117803049928714
# 3500it [10:31,  5.55it/s]
# 750it [00:33, 22.36it/s]
# #################### Epoch: 4 ####################
# Train loss: 2.3172517173290252 || Mean BLEU score: 0.4068810364193691 || One epoch training time: 0hrs 11mins 4secs
# Validation loss: 2.4004576665560404 || Mean Validation BLEU score: 0.4178626927207603
# 3500it [11:58,  4.87it/s]
# 750it [00:38, 19.48it/s]
# #################### Epoch: 5 ####################
# Train loss: 2.1635126913615634 || Mean BLEU score: 0.4130770414300886 || One epoch training time: 0hrs 12mins 37secs
# Validation loss: 2.2912527311642963 || Mean Validation BLEU score: 0.4249349384895645

# %%
sos_id=2
eos_id=3
pad_id=0
def greedy_search( e_output, e_mask):
        last_words = torch.LongTensor([pad_id] * seq_len).to(device)
        last_words[0] = sos_id # (L)
        cur_len = 1

        for i in range(seq_len):
            d_mask = (last_words.unsqueeze(0) != pad_id).unsqueeze(1).to(device)
            nopeak_mask = torch.ones([1, seq_len, seq_len], dtype=torch.bool).to(device)
            nopeak_mask = torch.tril(nopeak_mask)
            d_mask = d_mask & nopeak_mask

            trg_embedded = model.trg_embedding(last_words.unsqueeze(0))
            trg_positional_encoded = model.positional_encoder(trg_embedded)
            decoder_output = model.decoder(
                trg_positional_encoded,
                e_output,
                e_mask,
                d_mask)

            output = model.softmax(
                model.output_linear(decoder_output))

            output = torch.argmax(output, dim=-1)
            last_word_id = output[0][i].item()

            if i < seq_len-1:
                last_words[i+1] = last_word_id
                cur_len += 1

            if last_word_id == eos_id:
                break

        if last_words[-1].item() == pad_id:
            decoded_output = last_words[1:cur_len].tolist()
        else:
            decoded_output = last_words[1:].tolist()

        decoded_output = ' '.join([list(ukr_word_index.keys())[list(ukr_word_index.values()).index(i)] for i in decoded_output])

        return decoded_output



def translate_text(input_text):
    model.eval()
    input_seq = sentence_src_to_tokens(input_text, eng_word_index)

    input_seq_pad = pad_sequences_src([input_seq], max_target_len)

    src_data = torch.LongTensor(input_seq_pad[0]).unsqueeze(0).to(device)

    e_mask = (src_data != pad_id).unsqueeze(1).to(device)

    src_data = model.src_embedding(src_data)
    src_data = model.positional_encoder(src_data)
    e_output = model.encoder(src_data, e_mask)

    result = greedy_search(e_output, e_mask)

    return result





for test_pair in test_data:
    input_text, target_text = test_pair
    print(f'Input: {input_text}')
    print(f'Target: {target_text}')
    predicted_text = translate_text(input_text)
    print(f'Predicted: {predicted_text}')
    print('---')
# Out:
# Input: youre aggressive
# Target: ти агресивний
# Predicted: ти дуже зайнятий <eos>
# ---
# Input: tom is buying beer
# Target: том купує пива
# Predicted: том дуже любить <eos>
# ---
# Input: there was something else
# Target: там було щось ще
# Predicted: це було дуже добре <eos>
# ---
# Input: weve done that before
# Target: ми вже це робили раніше
# Predicted: ми це було <eos>
# ---
# Input: toms french is perfect
# Target: у тома бездоганна французька
# Predicted: це було скасовано <eos>
# ---
# Input: tom is giddy
# Target: у тома паморочиться в голові
# Predicted: том дуже пяний <eos>
# ---
# Input: please do it quickly
# Target: будь ласка зроби це швидко
# Predicted: це було б це зробити <eos>
# ---
# Input: i play in a band
# Target: я граю в групі
# Predicted: я в бостоні <eos>
# ---
# Input: we love your books
# Target: ми любимо твої книжки
# Predicted: ми маємо подобається <eos>
# ---
# Input: i read the old documents
# Target: я читав старі документи
# Predicted: я люблю грати в бостоні <eos>
# ---
# Input: tom stole marys lunch
# Target: том поцупив обід мері
# Predicted: том любить мері <eos>
# ---
# Input: its the last one
# Target: це останній
# Predicted: він був у 2013 <eos>
# ---
# Input: i swear its not my fault
# Target: клянуся це не моя провина
# Predicted: я не можу знайти <eos>
# ---
# Input: its hard
# Target: це складно
# Predicted: це дуже добре <eos>
# ---
# Input: ive got no friends
# Target: у мене немає друзів
# Predicted: я не маю рації <eos>
# ---
# Input: tom drew me a picture
# Target: том намалював мені картинку
# Predicted: том мене був <eos>
# ---
# Input: we have some problems
# Target: у нас є певні проблеми
# Predicted: ми маємо план <eos>
# ---
# Input: we got sick
# Target: ми захворіли
# Predicted: ми маємо <eos>
# ---
# Input: im kind of tired today
# Target: я сьогодні трохи втомився
# Predicted: я сьогодні вже тут <eos>
# ---
# Input: will you buy something
# Target: ти щось купуватимеш
# Predicted: ти любиш <eos>
# ---
# Input: tom and mary kept silent
# Target: том та мері були мовчазні
# Predicted: том та мері дуже зайнятий <eos>
# ---
# Input: tom wont help us
# Target: том нам не допоможе
# Predicted: том не може допомогти <eos>
# ---
# Input: we all desire success
# Target: ми всі прагнемо успіху
# Predicted: ми всі тут є час <eos>
# ---
# Input: its a simple mistake
# Target: це проста помилка
# Predicted: це було дуже холодно <eos>
# ---
# Input: theres a telephone here
# Target: тут є телефон
# Predicted: це сьогодні <eos>
# ---
# Input: i have a girlfriend
# Target: я маю подругу
# Predicted: я маю мері <eos>
# ---
# Input: take off your socks
# Target: зніміть шкарпетки
# Predicted: дай мені <eos>
# ---
# Input: tom knows us
# Target: том нас знає
# Predicted: том нам не міг би <eos>
# ---
# Input: you should see a doctor
# Target: вам слід звернутися до лікаря
# Predicted: ти можеш скористатися моєю <eos>
# ---
# Input: we still have more time
# Target: ми все ще маємо час
# Predicted: ми всі тут ще раз <eos>
# ---
# Input: i enjoy playing chess
# Target: мені подобаються шахи
# Predicted: я люблю грати в бостоні <eos>
# ---
# Input: are you feeling sick
# Target: ви почуваєте себе хворим
# Predicted: ти дуже добре <eos>
# ---
# Input: youre not hard to find
# Target: вас нескладно знайти
# Predicted: це не може бути правдою <eos>
# ---
# Input: ill see you monday
# Target: побачимося в понеділок
# Predicted: я хочу щоб ти в бостоні <eos>
# ---
# Input: now i have to find tom
# Target: тепер мені потрібно знайти тома
# Predicted: я маю мері що том <eos>
# ---
# Input: i like folk songs
# Target: я люблю народні пісні
# Predicted: я люблю читати <eos>
# ---
# Input: where are we exactly
# Target: де саме ми знаходимося
# Predicted: де ми маємо <eos>
# ---
# Input: youre average students
# Target: ви середньостатистичні учні
# Predicted: це було дуже холодно <eos>
# ---
# Input: tom wont be doing that
# Target: том не буде цим займатися
# Predicted: том не був це не був <eos>
# ---
# Input: he has a good brain
# Target: він має добрі мізки
# Predicted: він дуже добре провели <eos>
# ---
# Input: tom wont find me
# Target: том мене не знайде
# Predicted: том не може допомогти <eos>
# ---
# Input: why dont you cry
# Target: чому ви не плачете
# Predicted: хіба ти не дуже зайнятий <eos>
# ---
# Input: you can stop
# Target: ти можеш припинити
# Predicted: ти можеш <eos>
# ---
# Input: how did tom get there
# Target: як том туди дістався
# Predicted: як том зробив <eos>
# ---
# Input: i definitely want to help
# Target: я звичайно ж хочу допомогти
# Predicted: я хочу щоб ти хочеш <eos>
# ---
# Input: i look like my mother
# Target: я схожа на матір
# Predicted: я люблю свою роботу <eos>
# ---
# Input: i like toms cat
# Target: мені подобається кішка тома
# Predicted: я люблю читати <eos>
# ---
# Input: i have drunk all my milk
# Target: я випила все своє молоко
# Predicted: я маю багато грошей <eos>
# ---
# Input: listen we need your help
# Target: послухайте нам потрібна ваша допомога
# Predicted: нам потрібна допомога <eos>
# ---
# Input: my decision was final
# Target: моє рішення було остаточним
# Predicted: мій батько <eos>
# ---
# Input: do you want to eat
# Target: хочете їсти
# Predicted: ти хочеш піти <eos>
# ---
# Input: my sister got engaged
# Target: моя сестра заручилася
# Predicted: у мене є машина <eos>
# ---
# Input: toms father is in jail
# Target: батько тома у вязниці
# Predicted: це моя <eos>
# ---
# Input: ive broken my glasses
# Target: я зламала свої окуляри
# Predicted: я був дуже зайнятий <eos>
# ---
# Input: tom needs to call mary
# Target: тому потрібно зателефонувати мері
# Predicted: том хоче мері <eos>
# ---
# Input: tom joined a fraternity
# Target: том вступив у братерство
# Predicted: том був дуже пяний <eos>
# ---
# Input: she looks like her aunt
# Target: вона схожа на свою тітку
# Predicted: вона купила з мері <eos>
# ---
# Input: tom wont let you leave
# Target: том не дозволить тобі піти
# Predicted: том тебе не вміє <eos>
# ---
# Input: i am talking with tom
# Target: я говорю з томом
# Predicted: я був у тома <eos>
# ---
# Input: tom doesnt snore
# Target: том на хропить
# Predicted: том не любить <eos>
# ---
# Input: your fly is open
# Target: у тебе розстебнута ширінька
# Predicted: де твій батько <eos>
# ---
# Input: where were you last year
# Target: де ви були минулого року
# Predicted: де ти був у бостоні <eos>
# ---
# Input: do you meditate
# Target: ви медитуєте
# Predicted: ти любиш <eos>
# ---
# Input: ive never smoked
# Target: я ніколи не палив
# Predicted: я ніколи не можу <eos>
# ---
# Input: youre very generous
# Target: ви дуже щедрий
# Predicted: це було дуже холодно <eos>
# ---
# Input: im scared of spiders
# Target: павуки мене лякають
# Predicted: я був дуже зайнятий <eos>
# ---
# Input: tom trusted mary
# Target: том довіряв мері
# Predicted: том був дуже засмучений <eos>
# ---
# Input: i did that too
# Target: я також це зробив
# Predicted: я вже це занадто <eos>
# ---
# Input: excuse me may i come in
# Target: перепрошую можна ввійти
# Predicted: я хочу щоб я хочу щоб я
# ---
# Input: were atheists
# Target: ми атеїстки
# Predicted: ми були пяні <eos>
# ---
# Input: please fix this
# Target: будь ласка полагодь це
# Predicted: це було весело <eos>
# ---
# Input: tom left home for work
# Target: том пішов із дому на роботу
# Predicted: том та мері на роботу <eos>
# ---
# Input: this cat is very fat
# Target: ця кішка дуже гладка
# Predicted: це дуже великий <eos>
# ---
# Input: may i ask your name
# Target: можна спитати як вас звуть
# Predicted: я можу знайти свою роботу <eos>
# ---
# Input: you cant divide by zero
# Target: ну нуль ділити не можна
# Predicted: ти не можу знайти <eos>
# ---
# Input: i didnt agree with that
# Target: я на таке не погоджувався
# Predicted: я не можу цього <eos>
# ---
# Input: ive already met tom
# Target: я вже знайома з томом
# Predicted: я був том сказав <eos>
# ---
# Input: i am eating rice
# Target: я зараз їм рис
# Predicted: я був дуже зайнятий <eos>
# ---
# Input: i wasnt invited
# Target: мене не було запрошено
# Predicted: я не дуже зайнятий <eos>
# ---
# Input: tom handed mary a towel
# Target: том простягнув мері рушника
# Predicted: том був дуже пяний <eos>
# ---
# Input: tom is a dad too
# Target: том також батько
# Predicted: том дуже добре <eos>
# ---
# Input: this is a good sign
# Target: це добрий знак
# Predicted: це дуже добре <eos>
# ---
# Input: i dont think i like you
# Target: не думаю що ви мені подобаєтеся
# Predicted: я не знаю що ти знаєш <eos>
# ---
# Input: i like this show
# Target: мені подобається ця програма
# Predicted: я люблю грати в бостоні <eos>
# ---
# Input: tell tom youre sick
# Target: скажи тому що ти хвора
# Predicted: скажи тому що том <eos>
# ---
# Input: she is quiet
# Target: вона тиха
# Predicted: вона дуже холодно <eos>
# ---
# Input: why isnt tom resigning
# Target: чому том не звільняється
# Predicted: том не був дуже засмучений <eos>
# ---
# Input: go fly a kite
# Target: топай звідси
# Predicted: вони мають <eos>
# ---
# Input: tom deserves it
# Target: том на це заслуговує
# Predicted: том це зробив <eos>
# ---
# Input: tom is absent
# Target: том відсутній
# Predicted: том не дуже <eos>
# ---
# Input: im ready for the test
# Target: я готова до тесту
# Predicted: я був у бостоні <eos>
# ---
# Input: im at my house
# Target: я у себе вдома
# Predicted: я був у мене <eos>
# ---
# Input: im young at heart
# Target: я молодий серцем
# Predicted: я в бостоні <eos>
# ---
# Input: do you often eat out
# Target: ви часто їсте не вдома
# Predicted: ти часто піти <eos>
# ---
# Input: be proud of yourself
# Target: пишайся собою
# Predicted: у нас є діти <eos>
# ---
# Input: thats mildly disturbing
# Target: це викликає легке почуття огиди
# Predicted: це було дуже холодно <eos>
# ---
# Input: were in good company
# Target: ми у добрій компанії
# Predicted: ми маємо <eos>
# ---
# Input: my car is older than me
# Target: моя машина старша від мене
# Predicted: мій батько мені подобається <eos>
# ---
# Input: tom is an exorcist
# Target: том екзорцист
# Predicted: том дуже пяний <eos>
# ---
# Input: the knife is dull
# Target: ніж затупився
# Predicted: де знаходиться <eos>
# ---
# Input: tom eats a lot of meat
# Target: том їсть багато мяса
# Predicted: том дуже добре пахне <eos>
# ---
# Input: tom still hasnt come to
# Target: том і досі не прийшов до тями
# Predicted: том ще не може бути <eos>
# ---
# Input: i was talking to tom
# Target: я розмовляв із томом
# Predicted: я хотів би тома <eos>
# ---
# Input: look alive
# Target: швидше
# Predicted: вони мають <eos>
# ---
# Input: what a terrible mistake
# Target: яка жахлива помилка
# Predicted: що це було дуже холодно <eos>
# ---
# Input: were cousins
# Target: ми кузени
# Predicted: ми були пяні <eos>
# ---
# Input: there were 30 witnesses
# Target: було тридцять свідків
# Predicted: ми всі були пяні <eos>
# ---
# Input: tom drives slowly
# Target: том повільно водить
# Predicted: том був дуже засмучений <eos>
# ---
# Input: how do you know tom
# Target: звідки ви знаєте тома
# Predicted: як ти знаєш тома <eos>
# ---
# Input: i really like my job
# Target: я дуже люблю свою роботу
# Predicted: я люблю цю книжку <eos>
# ---
# Input: its under the chair
# Target: воно під стільцем
# Predicted: він любить <eos>
# ---
# Input: ill walk
# Target: я піду пішки
# Predicted: я ненавиджу <eos>
# ---
# Input: why was tom hugging mary
# Target: чому том обіймав мері
# Predicted: том був дуже засмучений <eos>
# ---
# Input: youve taken everything
# Target: ви забрали все
# Predicted: вони були пяні <eos>
# ---
# Input: tom has no alibi
# Target: у тома немає алібі
# Predicted: том не був розлючений <eos>
# ---
# Input: dont worry
# Target: не переймайся
# Predicted: не було <eos>
# ---
# Input: i think you did this
# Target: мені здається це ти це зробив
# Predicted: я знаю що ти зробив <eos>
# ---
# Input: well be waiting for you
# Target: ми на вас чекатимемо
# Predicted: ми можемо з тобою <eos>
# ---
# Input: im bossy
# Target: я владний
# Predicted: я дуже зайнятий <eos>
# ---
# Input: what could tom mean
# Target: що том міг мати на увазі
# Predicted: що том може бути правдою <eos>
# ---
# Input: he arrived too early
# Target: він приїхав зарано
# Predicted: він дуже добре провели <eos>
# ---
# Input: tom lives over there
# Target: том мешкає он там
# Predicted: том був дуже добре <eos>
# ---
# Input: tom doesnt smile
# Target: том не посміхається
# Predicted: том не любить <eos>
# ---
# Input: why do you want to die
# Target: чому ви хочете померти
# Predicted: ти хочеш піти <eos>
# ---
# Input: i have no grandchildren
# Target: у мене немає онуків
# Predicted: я не люблю <eos>
# ---
# Input: tom has two brothers
# Target: том має двох братів
# Predicted: том має три години <eos>
# ---
# Input: volcanoes are dangerous
# Target: вулкани небезпечні
# Predicted: вони були пяні <eos>
# ---
# Input: its good
# Target: він добрий
# Predicted: це дуже добре <eos>
# ---
# Input: tom is my name
# Target: мене звати том
# Predicted: том мій батько <eos>
# ---
# Input: i know that youre angry
# Target: я знаю що ти сердита
# Predicted: я знаю що це зробити <eos>
# ---
# Input: do you hear me
# Target: ви мене чуєте
# Predicted: ти мене не хочеш <eos>
# ---
# Input: i stayed at a cheap hotel
# Target: я зупинилася у дешевому готелі
# Predicted: я дуже добре провели <eos>
# ---
# Input: i wasnt here yesterday
# Target: мене тут вчора не було
# Predicted: я тут не тут <eos>
# ---
# Input: you have a good memory
# Target: у тебе добра память
# Predicted: ти дуже добре <eos>
# ---
# Input: i came by bus
# Target: я приїхала на автобусі
# Predicted: я був у тома <eos>
# ---
# Input: tom is a deer hunter
# Target: том мисливець на оленів
# Predicted: том був дуже пяний <eos>
# ---
# Input: i baked tom a cake
# Target: я випік тому пиріг
# Predicted: я був дуже засмучений <eos>
# ---
# Input: get into the car
# Target: сідайте до машини
# Predicted: дай мені <eos>
# ---
# Input: tom wants children
# Target: том хоче дітей
# Predicted: том любить мері <eos>
# ---
# Input: someone came in
# Target: хтось увійшов
# Predicted: він у нас в порядку <eos>
# ---
# Input: we can win this war
# Target: ми можемо перемогти у цій війні
# Predicted: ми можемо бути правдою <eos>
# ---
# Input: i feel quite bad
# Target: я досить таки погано почуваюся
# Predicted: я хочу бути правдою <eos>
# ---
# Input: keep quiet
# Target: тиша
# Predicted: будь ласка <eos>
# ---
# Input: he can be relied on
# Target: на нього можна розраховувати
# Predicted: він може бути у нас <eos>
# ---
# Input: did you ask the price
# Target: ти запитала про ціну
# Predicted: ти купила <eos>
# ---
# Input: get back to the ship
# Target: повертайстеся на корабель
# Predicted: дай мені свій компютер <eos>
# ---
# Input: lets wait a while
# Target: давайте трохи зачекємо
# Predicted: йди додому <eos>
# ---
# Input: hes a teetotaller
# Target: він непитущий
# Predicted: це було дуже холодно <eos>
# ---
# Input: tom speaks some french
# Target: том трохи може говорити французькою
# Predicted: том був дуже любить <eos>
# ---
# Input: she kept working
# Target: вона продовжила працювати
# Predicted: вона була дуже холодно <eos>
# ---
# Input: we have pictures
# Target: ми маємо фотографії
# Predicted: ми маємо <eos>
# ---
# Input: you are a doctor
# Target: ти лікар
# Predicted: ти любиш <eos>
# ---
# Input: do you want to go
# Target: хочеш піти
# Predicted: ти хочеш піти <eos>
# ---
# Input: im afraid to go home
# Target: я боюся їхати додому
# Predicted: я хочу бути у бостоні <eos>
# ---
# Input: ive already been there
# Target: я там вже бував
# Predicted: я вже все ще не був <eos>
# ---
# Input: i need you to trust me
# Target: мені потрібно щоб ви мені довіряли
# Predicted: мені потрібна допомога мені <eos>
# ---
# Input: mary came in
# Target: мері увійшла
# Predicted: він у нас в порядку <eos>
# ---
# Input: kill them
# Target: вбий їх
# Predicted: дай мені <eos>
# ---
# Input: do it again
# Target: зроби це знову
# Predicted: це було б <eos>
# ---
# Input: wheres your assistant
# Target: де твій асистент
# Predicted: де твій батько <eos>
# ---
# Input: i think tom is handsome
# Target: мені здається том гарний
# Predicted: я знаю що том був дуже зайнятий
# ---
# Input: i burned it
# Target: я її спалив
# Predicted: я це зробив <eos>
# ---
# Input: turn off the alarm
# Target: вимкни сигналізацію
# Predicted: дай <eos>
# ---
# Input: what total nonsense
# Target: яке маячення
# Predicted: що це було весело <eos>
# ---
# Input: keep still
# Target: не рухайся
# Predicted: вони ще раз <eos>
# ---
# Input: i am from tokyo
# Target: я з токіо
# Predicted: я в бостоні <eos>
# ---
# Input: ill need some help
# Target: мені буде потрібна допомога
# Predicted: я хочу щоб допомогти <eos>
# ---
# Input: why are you so smart
# Target: чому ти така розумна
# Predicted: ти дуже добре <eos>
# ---
# Input: do you have a cellphone
# Target: у вас є мобільний телефон
# Predicted: ти маєш рацію <eos>
# ---
# Input: we love our country
# Target: ми любимо свою країну
# Predicted: ми маємо план <eos>
# ---
# Input: tom talks quickly
# Target: том розвмовляє швидко
# Predicted: том був дуже засмучений <eos>
# ---
# Input: do you like indian food
# Target: тобі подобаються страви індійської кухні
# Predicted: ти любиш твоя мама <eos>
# ---
# Input: tom wasnt reading
# Target: том не читав
# Predicted: том не був дуже зайнятий <eos>
# ---
# Input: it was all an act
# Target: це була лише гра
# Predicted: це було дуже добре <eos>
# ---
# Input: are you able to do that
# Target: умієш так робити
# Predicted: ти це зробити <eos>
# ---
# Input: i live in the city
# Target: я живу в місті
# Predicted: я хочу бути у вязниці <eos>
# ---
# Input: we must intervene
# Target: ми мусимо втрутитися
# Predicted: ми маємо слід <eos>
# ---
# Input: youre very disorganized
# Target: ви дуже неорганізовані
# Predicted: це було дуже холодно <eos>
# ---
# Input: he is my teacher
# Target: він мій викладач
# Predicted: він мій син <eos>
# ---
# Input: ill miss tom
# Target: мені бракуватиме тома
# Predicted: я забув тому <eos>
# ---
# Input: im unable to walk
# Target: я не можу ходити
# Predicted: я хотів би щоб я <eos>
# ---
# Input: i drank tea
# Target: я випила чаю
# Predicted: я дуже добре провели <eos>
# ---
# Input: who did tom talk to
# Target: з ким розмовляв том
# Predicted: хто хоче тома <eos>
# ---
# Input: she studies hard
# Target: вона багато вчиться
# Predicted: вона дуже добре пахне <eos>
# ---
# Input: i have ocd
# Target: у мене окр
# Predicted: я маю дуже зайнятий <eos>
# ---
# Input: say it isnt true
# Target: скажи що це неправда
# Predicted: що це не так <eos>
# ---
# Input: ive heard of you
# Target: я чув про вас
# Predicted: я знаю що ти знаєш <eos>
# ---
# Input: she loves cats
# Target: вона обожнює котів
# Predicted: вона дуже добре <eos>
# ---
# Input: tom is a cop
# Target: том коп
# Predicted: том дуже пяний <eos>
# ---
# Input: you cant prove that
# Target: ти не можеш цього довести
# Predicted: ти не можу це зробити <eos>
# ---
# Input: nobody is speaking
# Target: ніхто не розмовляє
# Predicted: це дуже добре <eos>
# ---
# Input: i knew youd like boston
# Target: я знала що вам сподобається бостон
# Predicted: я знаю що том знав <eos>
# ---
# Input: youre always late
# Target: ти завжди запізнюєшся
# Predicted: це було дуже холодно <eos>
# ---
# Input: were not going to do it
# Target: ми не будемо цього робити
# Predicted: ми не можемо це зробити <eos>
# ---
# Input: no no thats not right
# Target: ні ні так не можна
# Predicted: не було не було <eos>
# ---
# Input: i wore my favorite dress
# Target: я була в улюбленному платті
# Predicted: я був у мене болить голова <eos>
# ---
# Input: do you want some pizza
# Target: хочеш піци
# Predicted: ти хочеш <eos>
# ---
# Input: why couldnt tom do that
# Target: чому том не зміг цього зробитии
# Predicted: том не може бути з мері <eos>
# ---
# Input: its almost over
# Target: майже скінчилося
# Predicted: це не було <eos>
# ---
# Input: i need to wash my car
# Target: мені потрібно помити машину
# Predicted: мені потрібна допомога <eos>
# ---
# Input: im toms father
# Target: я тато тома
# Predicted: я купив тому <eos>
# ---
# Input: did tom open the door
# Target: том відчинив двері
# Predicted: том був у бостоні <eos>
# ---
# Input: what is it that you want
# Target: чого саме ти хочеш
# Predicted: що ти це зробити <eos>
# ---
# Input: she used to love him
# Target: вона його колись кохала
# Predicted: вона купила з ним <eos>
# ---
# Input: my whole body is sore
# Target: у мене все тіло болить
# Predicted: мій будинок <eos>
# ---
# Input: im stronger than you
# Target: я сильніший від тебе
# Predicted: я хотіла би тобі <eos>
# ---
# Input: my father died of cancer
# Target: батько помер від раку
# Predicted: мій батько <eos>
# ---
# Input: i played the piano
# Target: я грав на піаніно
# Predicted: я був у бостоні <eos>
# ---
# Input: whats the date today
# Target: яке сьогодні число
# Predicted: сьогодні вже тут <eos>
# ---
# Input: he made me a suit
# Target: він зшив мені костюм
# Predicted: він був у мене є <eos>
# ---
# Input: tom didnt want to swim
# Target: том не хотів плавати
# Predicted: том не хочу щоб мері <eos>
# ---
# Input: it needs to be fixed
# Target: це треба виправити
# Predicted: це було б це зробити <eos>
# ---
# Input: why are you crying
# Target: чому ви плачете
# Predicted: ти дуже зайнятий <eos>
# ---
# Input: where are the horses
# Target: де коні
# Predicted: де знаходиться <eos>
# ---
# Input: dont lie to tom
# Target: не бреши тому
# Predicted: не кажіть тома <eos>
# ---
# Input: call the police
# Target: викличте поліцію
# Predicted: дайте до школи <eos>
# ---
# Input: who broke the bottle
# Target: хто розбив пляшку
# Predicted: хто хоче побачити <eos>
# ---
# Input: tom drew a large square
# Target: том намалював великий квадрат
# Predicted: том був дуже швидко <eos>
# ---
# Input: im quitting
# Target: я припиняю
# Predicted: я дуже зайнятий <eos>
# ---
# Input: everything is working
# Target: усе працює
# Predicted: це дуже добре <eos>
# ---
# Input: i dont like school
# Target: я не люблю школу
# Predicted: я не люблю <eos>
# ---
# Input: im busy with homework
# Target: я зайнята домашнім завданням
# Predicted: я був у понеділок <eos>
# ---
# Input: christmas is soon right
# Target: скоро різдво чи не так
# Predicted: це було б це зробити <eos>
# ---
# Input: its your money
# Target: це твої гроші
# Predicted: де твоя дружина <eos>
# ---
# Input: english is easy to learn
# Target: англійську легко вивчити
# Predicted: йди додому <eos>
# ---
# Input: why would you do that
# Target: чому б ти це робив
# Predicted: ти це зробити <eos>
# ---
# Input: are you being serious
# Target: ти серйозно
# Predicted: ти дуже задоволений <eos>
# ---
# Input: tom is blind in one eye
# Target: том сліпий на одне око
# Predicted: том у бостоні <eos>
# ---
# Input: i think its toms turn
# Target: гадаю зараз черга тома
# Predicted: я хочу щоб ти виглядаєш <eos>
# ---
# Input: tom is very mad at mary
# Target: том дуже злий на мері
# Predicted: том був дуже добре <eos>
# ---
# Input: i know tom is a weird guy
# Target: я знаю що том дивакуватий
# Predicted: я знаю що том дуже зайнятий <eos>
# ---
# Input: tom values the truth
# Target: том цінує правду
# Predicted: том каже що мері <eos>
# ---
# Input: you did your part
# Target: ти зробила свою частину
# Predicted: ти купила <eos>
# ---
# Input: its your only hope
# Target: це ваша єдина надія
# Predicted: йди додому <eos>
# ---
# Input: i was outside
# Target: я був надворі
# Predicted: я дуже зайнятий <eos>
# ---
# Input: ok you win
# Target: гаразд ти перемогла
# Predicted: ти маєш рацію <eos>
# ---
# Input: im bored
# Target: мені нудно
# Predicted: я дуже зайнятий <eos>
# ---
# Input: youre the smart one
# Target: ти тут розумна
# Predicted: де знаходиться дуже добре <eos>
# ---
# Input: turn the radio down
# Target: зробіть радіо тихіше
# Predicted: дай мені <eos>
# ---
# Input: im not a scientist
# Target: я не вчений
# Predicted: я не був наляканий <eos>
# ---
# Input: boy was i wrong
# Target: як же я помилялася
# Predicted: я був дуже зайнятий <eos>
# ---
# Input: i want to learn to knit
# Target: я хочу навчитися вязати
# Predicted: я хочу щоб ти хочеш <eos>
# ---
# Input: im too old for tom
# Target: я для тома застарий
# Predicted: я теж тома <eos>
# ---
# Input: i have a report to write
# Target: мені потрібно написати звіт
# Predicted: я маю багато часу <eos>
# ---
# Input: its merely a joke
# Target: та це просто жарт
# Predicted: це було дуже великий <eos>
# ---
# Input: can tom understand french
# Target: том розуміє французьку
# Predicted: том може бути правдою <eos>
# ---
# Input: lets make a movie
# Target: давайте знімемо кіно
# Predicted: це було скасовано <eos>
# ---
# Input: wheres your car tom
# Target: де ваша машина томе
# Predicted: де твій батько <eos>
# ---
# Input: i was too busy last week
# Target: минулого тижня я була занадто зайнята
# Predicted: я щойно приїхав на роботу <eos>
# ---
# Input: i almost never get sick
# Target: я майже ніколи не хворію
# Predicted: я ніколи не можу <eos>
# ---
# Input: i lost my favorite pen
# Target: я загубив улюблену ручку
# Predicted: я купив новий телефон <eos>
# ---
# Input: i like this book best
# Target: мені ця книга подобається більше
# Predicted: я люблю цю книжку <eos>
# ---
# Input: tom is spirited
# Target: том палкий
# Predicted: том дуже пяний <eos>
# ---
# Input: do you like apple pies
# Target: тобі подобаються яблучні пироги
# Predicted: ти любиш <eos>
# ---
# Input: the decision is toms
# Target: рішення за томом
# Predicted: де знаходиться дуже холодно <eos>
# ---
# Input: no problem
# Target: жодних проблем
# Predicted: не було <eos>
# ---
# Input: i seem to be lost
# Target: я здається заблукала
# Predicted: я дуже добре провели <eos>
# ---
# Input: i can wait for you
# Target: я можу на тебе зачекати
# Predicted: я можу вам допомогти <eos>
# ---
# Input: tom is laughing at mary
# Target: том сміється над мері
# Predicted: том був у вязниці <eos>
# ---
# Input: i told tom id win
# Target: я сказав тому що виграю
# Predicted: я сказав що том сказав що том
# ---
# Input: youre not going to win
# Target: тобі не перемогти
# Predicted: це не було б <eos>
# ---
# Input: ive never swum in a pool
# Target: я ніколи не плавав у басейні
# Predicted: я ніколи не маю в бостоні <eos>
# ---
# Input: they found tom
# Target: вони знайшли тома
# Predicted: вони всі люблять тома <eos>
# ---
# Input: clearly you are mistaken
# Target: зрозуміло що ви помиляєтеся
# Predicted: ти не дуже зайнятий <eos>
# ---
# Input: ill call you tomorrow
# Target: я зателефоную тобі завтра
# Predicted: я хочу щоб ти тут <eos>
# ---
# Input: thats odd
# Target: дивна справа
# Predicted: це дуже добре <eos>
# ---
# Input: its not very important
# Target: це не дуже важливо
# Predicted: це не було <eos>
# ---
# Input: how can i help you
# Target: чим я можу допомогти
# Predicted: як ти знаєш що ти знаєш <eos>
# ---
# Input: dont look back
# Target: не озирайся
# Predicted: не йди <eos>
# ---
# Input: tom has a new truck
# Target: у тома нова вантажівка
# Predicted: том був удома <eos>
# ---
# Input: she took her own life
# Target: вона наклала на себе руки
# Predicted: вона купила новий будинок <eos>
# ---
# Input: tom lost the race
# Target: том програв перегони
# Predicted: том був у вязниці <eos>
# ---
# Input: tom was shocked
# Target: том був у шоці
# Predicted: том був дуже засмучений <eos>
# ---
# Input: youve drunk too much
# Target: ти забагато випила
# Predicted: це дуже добре <eos>
# ---
# Input: they swim very quickly
# Target: вони дуже швидко плавають
# Predicted: вони мають трохи поспати <eos>
# ---
# Input: the hole is big enough
# Target: дірка достатньо велика
# Predicted: де знаходиться дуже великий <eos>
# ---
# Input: you wouldnt believe it
# Target: ти би в це не повірив
# Predicted: ти не можу цього <eos>
# ---
# Input: when did you buy it
# Target: коли ти його купила
# Predicted: коли ти це зробив <eos>
# ---
# Input: she fell asleep
# Target: вона заснула
# Predicted: вона була змушена <eos>
# ---
# Input: how are things in boston
# Target: як справи в бостоні
# Predicted: як у нього в бостоні <eos>
# ---
# Input: please tell the truth
# Target: скажіть будь ласка правду
# Predicted: дай мені здається це <eos>
# ---
# Input: toms plan is simple
# Target: у тома простий план
# Predicted: це було дуже добре <eos>
# ---
# Input: tom almost drowned
# Target: том мало не потонув
# Predicted: том не дуже добре <eos>
# ---
# Input: tom didnt want to lie
# Target: том не хотів казати неправду
# Predicted: том не хочу щоб мері <eos>
# ---
# Input: im not wearing socks
# Target: я не в шкарпетках
# Predicted: я не дуже зайнятий <eos>
# ---
# Input: tom will meet you there
# Target: том тебе там зустріне
# Predicted: том може бути з тобою <eos>
# ---
# Input: warn your friends
# Target: попередьте своїх друзів
# Predicted: де твій батько <eos>
# ---
# Input: do you follow
# Target: ти розумієш
# Predicted: ти любиш <eos>
# ---
# Input: stay at home
# Target: залишайтесь удома
# Predicted: йди додому <eos>
# ---
# Input: dont stand near me
# Target: не стій біля мене
# Predicted: не забувай мене <eos>
# ---
# Input: i switched the lamp off
# Target: я вимкнув лампу
# Predicted: я був змушений <eos>
# ---
# Input: the men are hungry
# Target: чоловіки голодні
# Predicted: де знаходиться <eos>
# ---
# Input: i see a light
# Target: я бачу світло
# Predicted: я люблю піцу <eos>
# ---
# Input: wherere the shoes
# Target: де взуття
# Predicted: де знаходиться <eos>
# ---
# Input: its not explainable
# Target: це неможливо пояснити
# Predicted: це не було <eos>
# ---
# Input: i was eating a sandwich
# Target: я їла канапку
# Predicted: я дуже високий <eos>
# ---
# Input: tom is a good boy
# Target: том добрий хлопець
# Predicted: том дуже добрий <eos>
# ---
# Input: i know tom is bald
# Target: я знаю що том лисий
# Predicted: я знаю що том був <eos>
# ---
# Input: theyre drunk
# Target: вони пяні
# Predicted: це не було <eos>
# ---
# Input: how can i contact tom
# Target: як я можу звязатися з томом
# Predicted: як я можу знайти тома <eos>
# ---
# Input: put it on toms tab
# Target: запишіть це на разунок тома
# Predicted: дай це було <eos>
# ---
# Input: i couldnt speak
# Target: я не могла говорити
# Predicted: я не можу <eos>
# ---
# Input: i have a dog and a cat
# Target: у мене є кіт і собака
# Predicted: я маю багато грошей <eos>
# ---
# Input: do you have any allergies
# Target: у тебе є на щось алергія
# Predicted: ти маєш рацію <eos>
# ---
# Input: tom frowned at mary
# Target: том насупився на мері
# Predicted: том був у вязниці <eos>
# ---
# Input: toms bored
# Target: тому нудно
# Predicted: ти дуже зайнятий <eos>
# ---
# Input: youll change your mind
# Target: ти передумаєш
# Predicted: ти любиш твоя мама <eos>
# ---
# Input: it smells bad
# Target: він погано пахне
# Predicted: це було дуже добре <eos>
# ---
# Input: how was boston
# Target: що там у бостоні
# Predicted: як пройшов у бостоні <eos>
# ---
# Input: let me see it
# Target: дайно подивлюся
# Predicted: дай мені це <eos>
# ---
# Input: tom took monday off
# Target: том узяв відгул на понеділок
# Predicted: том був у бостоні <eos>
# ---
# Input: it isnt that easy
# Target: це не так просто
# Predicted: це не було <eos>
# ---
# Input: im afraid tom will lose
# Target: боюся том програє
# Predicted: я ненавиджу <eos>
# ---
# Input: turn off the television
# Target: вимкніть телевізор
# Predicted: давайте <eos>
# ---
# Input: tom backed up his data
# Target: том забекапив свої дані
# Predicted: том любить мері <eos>
# ---
# Input: come to my house
# Target: приходь до мене
# Predicted: йди додому <eos>
# ---
# Input: math is hard
# Target: математика складна
# Predicted: це дуже добре <eos>
# ---
# Input: call a doctor
# Target: викличте лікаря
# Predicted: дай мені <eos>
# ---
# Input: i need a map
# Target: мені потрібна карта
# Predicted: мені потрібна допомога <eos>
# ---
# Input: youre brave
# Target: ви сміливі
# Predicted: ти дуже зайнятий <eos>
# ---
# Input: i hate this
# Target: я це дуже не люблю
# Predicted: я ненавиджу <eos>
# ---
# Input: tom is still in a coma
# Target: том і досі в комі
# Predicted: том ще раз <eos>
# ---
# Input: it was ours
# Target: це було наше
# Predicted: це було дуже холодно <eos>
# ---
# Input: were introverted
# Target: ми інтроверти
# Predicted: ми були пяні <eos>
# ---
# Input: please wrap them up
# Target: загорніть їх будь ласка
# Predicted: давайте будь ласка <eos>
# ---
# Input: lets try it again
# Target: спробуймо ще раз
# Predicted: це було б це було не було
# ---
# Input: this is an order
# Target: це наказ
# Predicted: це було скасовано <eos>
# ---
# Input: what he said is not true
# Target: те що він сказав неправда
# Predicted: що він не так <eos>
# ---
# Input: im not coming with you
# Target: я з вами не їду
# Predicted: я не можу вам <eos>
# ---
# Input: they love coffee
# Target: вони люблять каву
# Predicted: вони хочуть <eos>
# ---
# Input: his car remained locked
# Target: його машина залишилася замкненою
# Predicted: це моя дружина <eos>
# ---
# Input: tom is exhausted
# Target: том виснажений
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-cecac507fdb5> in <cell line: 69>()
#      71     print(f'Input: {input_text}')
#      72     print(f'Target: {target_text}')
# ---> 73     predicted_text = translate_text(input_text)
#      74     print(f'Predicted: {predicted_text}')
#      75     print('---')
#
# <ipython-input-15-cecac507fdb5> in translate_text(input_text)
#      59     e_output = model.encoder(src_data, e_mask)
#      60
# ---> 61     result = greedy_search(e_output, e_mask)
#      62
#      63     return result
#
# <ipython-input-15-cecac507fdb5> in greedy_search(e_output, e_mask)
#      15             trg_embedded = model.trg_embedding(last_words.unsqueeze(0))
#      16             trg_positional_encoded = model.positional_encoder(trg_embedded)
# ---> 17             decoder_output = model.decoder(
#      18                 trg_positional_encoded,
#      19                 e_output,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-13-08b6fdb32a45> in forward(self, x, e_output, e_mask, d_mask)
#     222     def forward(self, x, e_output, e_mask, d_mask):
#     223         for i in range(num_layers):
# --> 224             x = self.layers[i](x, e_output, e_mask, d_mask)
#     225
#     226         return self.layer_norm(x)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-13-08b6fdb32a45> in forward(self, x, e_output, e_mask, d_mask)
#      61         ) # (B, L, d_model)
#      62         x_3 = self.layer_norm_3(x) # (B, L, d_model)
# ---> 63         x = x + self.drop_out_3(self.feed_forward(x_3)) # (B, L, d_model)
#      64
#      65         return x # (B, L, d_model)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-13-08b6fdb32a45> in forward(self, x)
#     130
#     131     def forward(self, x):
# --> 132         x = self.relu(self.linear_1(x)) # (B, L, d_ff)
#     133         x = self.dropout(x)
#     134         x = self.linear_2(x) # (B, L, d_model)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt


# Витягуємо значення втрати та метрики accuracy з історії
loss = history.history['loss']
accuracy = history.history['accuracy']

# Побудова графіка для втрати
plt.plot(range(1, len(loss) + 1), loss, label='Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Побудова графіка для accuracy
plt.plot(range(1, len(accuracy) + 1), accuracy, label='Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
